# %% [markdown]
# # B"H

# %% [markdown]
# ## Env Setup

# %%
import sys
import os
from pathlib import Path

# %%
print(f"Python executable: {sys.executable}")
print(f"Python version: {sys.version.split()[0]}")
print(f"Virtual env prefix: {sys.prefix}")
# Out:
# Python executable: /home/izzy/repos/repos-p5/pointfive/ai-tag-intelligence/.venv/bin/python
# Python version: 3.12.10
# Virtual env prefix: /home/izzy/repos/repos-p5/pointfive/ai-tag-intelligence/.venv

# %%
assert sys.executable == '/home/izzy/repos/repos-p5/pointfive/ai-tag-intelligence/.venv/bin/python'

# %%
src_path = Path(os.environ.get('AI_AGENT_DIR')) / "src"
assert src_path.is_dir()

if str(src_path) not in sys.path:
    sys.path.insert(0, str(src_path))

print(str(src_path))
# Out:
# /home/izzy/repos/repos-p5/pointfive/ai-tag-intelligence/src

# %%
sys.path
# Out:
# ['/home/izzy/repos/repos-p5/pointfive/ai-tag-intelligence/src',
#  '/home/izzy/.local/share/mise/installs/python/3.12.10/lib/python312.zip',
#  '/home/izzy/.local/share/mise/installs/python/3.12.10/lib/python3.12',
#  '/home/izzy/.local/share/mise/installs/python/3.12.10/lib/python3.12/lib-dynload',
#  '',
#  '/home/izzy/repos/repos-p5/pointfive/ai-tag-intelligence/.venv/lib/python3.12/site-packages',
#  '/home/izzy/repos/repos-p5/pointfive/ai-tag-intelligence']

# %% [markdown]
# ## Constants

# %%
from pathlib import Path

LARGE_FILES_DIR = Path('/home/izzy/repos/x-large-files/x-large-files-p5-tag-intelligence')
assert LARGE_FILES_DIR.is_dir()

# -- -----------------------------
ITERATION_NAME = 'deep-research-02'

ITERATION_DIR = LARGE_FILES_DIR / ITERATION_NAME
if not ITERATION_DIR.exists():
    ITERATION_DIR.mkdir()

# -- -----------------------------
COMPONENTS_AGG_INFO_FILE = ITERATION_DIR / 'components-agg-info.json'
assert COMPONENTS_AGG_INFO_FILE.exists()


CONSOLIDATOR_BATCH_ID_FILE = ITERATION_DIR / 'consolidator-batch-id.txt'

# -- -----------------------------
GCS_BUCKET = os.getenv("GCS_BUCKET")
print(GCS_BUCKET)
# Out:
# ai-tag-intelligence

# %% [markdown]
# ## Data Peek

# %%
import pandas as pd

# %%
df = pd.read_json(COMPONENTS_AGG_INFO_FILE)

df.head()
# Out:
#          category                                      sample_values
# 0     Environment  fdprod (FD Production), xprep (preparation/sta...
# 1  Project/System  sce (SCE product/project), cchh9cfqg3ymhauu8qq...
# 2  Service/Domain  portal-extns (Portal Extensions), warrsup, ifs...
# 3   Resource Type  engine, cluster (ECSCluster), doc (document), ...
# 4     Application  lawson, auth, pges, openedge (OpenEdge applica...

# %% [markdown]
# ## GenAI Client

# %%
import os
import json
from google import genai
from google.genai.types import HttpOptions

# Initialize Google GenAI client for Vertex AI
client = genai.Client(
    http_options=HttpOptions(api_version="v1"),
    vertexai=True,
    project=os.getenv("ANTHROPIC_VERTEX_PROJECT_ID"),
    location=os.getenv("CLOUD_ML_REGION")
)

# %% [markdown]
# ## PROMPT_TEMPLATE_TO_CACHE

# %%
PROMPT_TEMPLATE_TO_CACHE = '''
You will analyze AWS resource categories to identify potential consolidation opportunities. Your task is to determine whether a specific category should be consolidated with another similar category from a comprehensive list.

Here is the complete list of all AWS resource categories:

<all_categories>
{all_categories}
</all_categories>
'''

# %% [markdown]
# ## PROMPT_TEMPLATE_PART_2

# %%
PROMPT_TEMPLATE_PART_2 = '''

You are an AWS resource categorization analyst tasked with identifying consolidation opportunities between similar resource categories.

Here is the specific category you need to analyze for potential consolidation:

<specific_category>
{specific_category}
</specific_category>

## Your Task

Your goal is to determine whether the specific category should be consolidated with any other category from the all_categories list. Two categories should only be consolidated if they represent essentially the same concept and have very similar sample values.

## Analysis Process

Before making your final recommendation, you must conduct a systematic analysis in <analysis> tags inside your thinking block. It's OK for this section to be quite long. Follow this structured approach:

1. **Record Key Information**: Write out the specific category name and quote its sample values verbatim to keep them clearly in focus.

2. **Systematic Comparison**: Review each category in the all_categories list (excluding exact matches of your specific_category, since a category cannot be consolidated with itself). Create a list of potential consolidation candidates and note why each might be similar.

3. **Detailed Similarity Assessment**: For your top 3-5 most promising candidates, conduct detailed evaluation:
   - **PRIMARY FACTOR**: Compare sample values in detail - do they represent very similar things? Quote specific sample values from both categories and explain similarities/differences.
   - **SECONDARY FACTOR**: Compare category names - do they represent similar concepts? Explain the conceptual relationship.
   - Rate overall similarity for each candidate (high/medium/low).

4. **Identify Most Similar**: Explicitly identify which single category is most similar overall, even if you don't recommend consolidation.

5. **Make Consolidation Decision**: Apply strict criteria - only recommend consolidation when both sample values are very similar AND category names represent related concepts. Be conservative in your recommendations.

## Important Guidelines

- Focus primarily on sample values when making decisions, as these are more precise indicators than category names alone
- Consider semantic meaning and patterns in sample values, not just superficial similarities  
- Only suggest consolidation when there is clear, strong similarity
- The specific_category will appear in the all_categories list - ignore that exact match

## CRITICAL REQUIREMENT: Tool Call

After completing your analysis, you MUST call the process_category tool. This is not optional - every response must end with this tool call.

The tool requires these parameters:
- **category** (required): The name of the specific category being researched
- **most_similar_category** (required): The category from all_categories that is most similar (even if you don't recommend consolidation)
- **should_consolidate** (required): Boolean indicating whether consolidation is recommended
- **rationale** (required): Detailed explanation of your decision
- **new_consolidated_category_name** (optional): Only include if should_consolidate is true

Example tool call:
```
process_category(
    category="Example Category Name",
    most_similar_category="Most Similar Category Name",
    should_consolidate=false,
    rationale="Detailed explanation focusing on sample value differences and category name analysis..."
)
```

Begin your systematic analysis now, then call the process_category tool with your findings. Your final output should consist only of the tool call and should not duplicate or rehash any of the work you did in the thinking block.
'''

# %% [markdown]
# ## Prepare Batch

# %%
from layer_1_util_modules.general_util.serializer import load_json, load_str, dict_to_json_str

# %%
prompt_to_cache = PROMPT_TEMPLATE_TO_CACHE.format(
    all_categories=load_str(COMPONENTS_AGG_INFO_FILE)
)

print(prompt_to_cache)
# Out:
# You will analyze AWS resource categories to identify potential consolidation opportunities. Your task is to determine whether a specific category should be consolidated with another similar category from a comprehensive list.
#
# Here is the complete list of all AWS resource categories:
#
# <all_categories>
# [
#   {
#     "category":"Environment",
#     "sample_values":"fdprod (FD Production), xprep (preparation\/staging environment), bexarprod, lspeucentb (Farm), prdsing (production-staging environment), develop (development branch), PP2 (pre-production 2), m3cecritfixc (M3CE Critical Fix environment), cismt3devuse1 (development, US-East-1 region), acct (account)"
#   },
#   {
#     "category":"Project\/System",
#     "sample_values":"sce (SCE product\/project), cchh9cfqg3ymhauu8qqprd (unique identifier), ssmgf14 (SSMGF product cluster 14), tam93, tam178 (cluster identifier), ezrms (EZ RMS - Revenue Management System), mingleios06 (Mingle product cluster instance), str (product), rdr (RDR product), tam03"
#   },
#   {
#     "category":"Service\/Domain",
#     "sample_values":"portal-extns (Portal Extensions), warrsup, ifsregistry (IFS Registry service), oauth-keys, sumoIns (Sumo Logic Instrumentation), version-shift (version and shift management service), resume (functional domain), icb-tenant-provision-api (Infor Cloud Business tenant provisioning API service), idle, push (push-based deployment service)"
#   },
#   {
#     "category":"Resource Type",
#     "sample_values":"engine, cluster (ECSCluster), doc (document), execution (Lambda execution context), node (cluster node\/instance), onDemand (EC2 on-demand pricing model), handlers, jumpboxec2 (EC2 Bastion\/Jump Box), keys (cryptographic keys\/credentials), event (EventBridge)"
#   },
#   {
#     "category":"Application",
#     "sample_values":"lawson, auth, pges, openedge (OpenEdge application platform), update (database update operation), patch-automation, birstapp159, planner, access-validation, openedge (Progress OpenEdge Database Platform)"
#   },
#   {
#     "category":"Deployment Method",
#     "sample_values":"uninstall (operation), infra (infrastructure-level deployment), CLONE (Cloned Deployment), ingress (inbound traffic entry point), patch-baseline (Patch Baseline Configuration), blue (Blue-green deployment pattern), bluegreen (Blue-Green Deployment), push (Push-based deployment), terminate (shutdown action), rollingupgrade (Rolling Upgrade)"
#   },
#   {
#     "category":"Deployment Target",
#     "sample_values":"mingleca1 (mingle-canada-1), csccl, begaprd, cglprod, prcsukprod, cchpennstatehealthprdbl (Penn State Health Production Blue), vpc6 (Virtual Private Cloud 6), fdntest, con (consumer), mingleuse2 (us-east-2 region deployment)"
#   },
#   {
#     "category":"Environment\/Region",
#     "sample_values":"apne1 (AWS ap-northeast-1 region), wfmprdeuw2, mguseast (managed us-east), capreprd1 (Canada Production Region 1), lspuseast (US East region), minglese2 (Mingle Southeast Asia 2 - ap-southeast-2), puse1 (prod-us-east-1), prdapse2 (production-ap-southeast-2), prdapne1 (Production, ap-northeast-1), regency"
#   },
#   {
#     "category":"Deployment Identifier",
#     "sample_values":"474668416683 (AWS Account ID), attach212, UQBZ5C9PNWBCRX2K, usea1ddeg (US-East-1 Deployment Environment Code), EZRMSLRS04 (complete deployment name), jeragmprd, simuxdde, sr1, c1105796750300, amctst"
#   },
#   {
#     "category":"Deployment Variant",
#     "sample_values":"zdf, stopover, gecomaeprd, urmdev, blue, priority, iso, advrep, t20 (test\/QA variant 20), law"
#   },
#   {
#     "category":"Deployment Instance",
#     "sample_values":"usea1ddee (US-East-1 deployment instance), simons, minglese1 (Southeast Asia Region 1 deployment instance), 241, pod1, wfmstsupport700, LS01 (Lawson System instance 01), sl34, christusprd, inndxb2"
#   },
#   {
#     "category":"Resource Identifier",
#     "sample_values":"b (cluster node identifier), k (cluster node identifier), i (SQL Server cluster node), vpc65 (Virtual Private Cloud 65), g (SQL Server cluster node), ts, w (SQL Node W), m (SQL cluster node designation), cchjhdfzarbev9hnr5jprd, warrsup"
#   },
#   {
#     "category":"Cost-Center\/Business-Unit",
#     "sample_values":"safewaydem, militarycc, grc, isc (Infor Service Cloud), intlsostst, merchantsnonprod (Merchants Non-Production), BCCPRD, begadev, ahs, RMS"
#   },
#   {
#     "category":"Deployment Location",
#     "sample_values":"usea1dded, mingleeu1 (Mingle Europe Region 1), minglene1 (ap-northeast-1 region), m12use1b (module 12, us-east-1 region, variant b), derbyprd (Derby production), mgeuwest2, mingleca1 (Canada Central - Instance 1), apse2prda (ap-southeast-2 production), paiuse1 (PAI US-East-1), m12use1b (us-east-1 region)"
#   },
#   {
#     "category":"Region\/Location",
#     "sample_values":"mingleew2 (mingle eu-west-2), eu-west-2 (AWS EU-WEST-2 region), puse1 (Primary US-East-1), srusa (South Region USA), mgeucent1 (Managed EU Central 1), usea1ddec (us-east-1 region deployment), mgeucent1 (Mongoose-Europe-Central-1), ca-central-1 (Canada Central AWS Region), apn (Asia Pacific Northeast - ap-northeast-1), iad (Northern Virginia region identifier)"
#   },
#   {
#     "category":"Application\/Product",
#     "sample_values":"docs, ibp (Infor Business Process), birstprd3apne1 (Birst product, production environment, Asia Pacific Northeast 1 region), cchctsrrmrq6yaf77fsprdgr, mrm, mingle62 (Mingle product, cluster instance 62), healthlake, mingle60, cchbwlgdhke4tzemwhttrnbl, cpsbeuc1 (colemanpaas - EU Central 1)"
#   },
#   {
#     "category":"Application\/Function",
#     "sample_values":"collector, tagging-infrastructure (Kubernetes-based tagging infrastructure system), teardown-helper (cleanup utility), updateservicemetadata, elblogs (Elastic Load Balancer logs), start-stop (start\/stop control), updatesc (updates component), teardown (cleanup operation), imsinboundkey, keys"
#   },
#   {
#     "category":"Deployment\/Environment",
#     "sample_values":"usea1dded (us-east-1 deployment), usea1ddek (us-east-1 region, ddek environment), minglene1 (deployment identifier for ap-northeast-1 region), newrel (new release), wfmseuc1 (WFM Southeast EU Central 1), mingleuse2 (mingle US-East-2 deployment), d013, sxe27, 24gov (2024 Government), oxford (deployment identifier)"
#   },
#   {
#     "category":"Application\/System",
#     "sample_values":"paengine, ifs (Infor Financial Suite integration), sqldiff, btm (Business Transaction Module), ohip, minglecqa14 (Mingle product, CQA environment, instance 14), dmp, birstapp325 (Birst Analytics Cluster 325), cpprdapne1 (Coleman PaaS Product - Asia Pacific Northeast 1 region), xdde"
#   },
#   {
#     "category":"Application\/Service",
#     "sample_values":"esbadapteritemmaster (ESB - Enterprise Service Bus adapter for item master data), runner (GitLab Runner), btm, telegraf (open-source metrics collection tool), crm (Customer Relationship Management), bulk-update, yellowfin, ifsui (Infor Financial Suite UI), reports, lambdaedge (AWS Lambda@Edge)"
#   },
#   {
#     "category":"Product\/System",
#     "sample_values":"ion (ION - Infor's integration platform), hms (Health Management System), rms (Restaurant Management System), gtndo1, eln (ELN Product), wfm (WFM - Workforce Management), ionce, ion (Infor Operating Network), ELN, gtnod1b"
#   },
#   {
#     "category":"Environment\/Instance",
#     "sample_values":"sxe83, cchchompprdbl, minglese2, mgtrain11 (Management Training environment, instance 11), cchcchdevtstpp8 (development\/test environment instance identifier), sxe26, cismtintuse1, m3perf01 (M3 Performance Environment, Instance 01), wfmsecinstg (WFM Security Instance Group), LS01 (Lawson System instance)"
#   },
#   {
#     "category":"Region",
#     "sample_values":"eu-west-2 (AWS region: EU West 2), cac1 (Canada Central 1), apse2 (ap-southeast-2), usw2 (us-west-2), mguseast1 (managed us-east-1), puse1 (us-east-1), mgapse2 (ap-southeast-2 - Asia Pacific Southeast 2), ap-northeast-1 (Asia Pacific Northeast Region 1), use1 (US-EAST-1), eu-west-2 (EU West 2 - London)"
#   },
#   {
#     "category":"Deployment Region",
#     "sample_values":"mingleca1 (Canada Central region - ca-central-1), iad (AWS IAD region), seuc1 (south-europe-central-1), paiuse1 (US East 1 region), mingleeu1 (Europe region 1 deployment), paiuse2 (PAI US-East-2), minglene1 (ap-northeast-1 region), mingleeu1 (eu1 = Europe Region 1), mgeuwest2, eu-west-2 (AWS London region)"
#   },
#   {
#     "category":"Resource Purpose",
#     "sample_values":"td (temporary data), datalake, background, credentials, collector (data collection agent), disabled-users (users with disabled status), rds (Relational Database Service), policies, database, patcher (patch management tool)"
#   },
#   {
#     "category":"Function\/Purpose",
#     "sample_values":"monitoring, secrets, cost, secret (management), redismaintenance (Redis Maintenance), drainer, tracking, reindexer, rotatekeys (key rotation function), alert (monitoring\/alerting)"
#   },
#   {
#     "category":"Service\/Component",
#     "sample_values":"workbench, provider, janus, ifsui (IFS UI component), loadmgr (Load Manager), job, coresecscheduler (Core Security Scheduler), shredderlmg (Shredder Lifecycle Management), apigateway (AWS API Gateway), metrics (monitoring\/metrics collection)"
#   },
#   {
#     "category":"Product\/Application",
#     "sample_values":"ipf, mscm (Infor Managed Supply Chain Management), cchuofmprdgr (cch product), mscm, cch (CCH Cloverleaf), mscm (Manufacturing Supply Chain Management), mingle, inforos, icb (Infor Cloud Business), scr"
#   },
#   {
#     "category":"Version\/Release",
#     "sample_values":"updates-08 (update iteration 08), rel202601 (Release 2026-01), 01 (Month\/Iteration), 2023-10 (October 2023), lsp2208newrc (LSP 2208 New Release Candidate), pre3 (pre-release version 3), 10 (October\/iteration), sxe25 (version 25), u (Update\/Version 10), 2022-04 (April 2022)"
#   },
#   {
#     "category":"Deployment",
#     "sample_values":"04ionce, dsdatrain, 100, m3suse1, lspuseastb, paiuse1 (us-east-1 region deployment), dcjyjdev, ft32, 2025-06 (Release Date), d334"
#   },
#   {
#     "category":"Application\/Component",
#     "sample_values":"settings, engine, lclsp (LCLSP plugin), scanner, controller, powershelltools, dbup (Database Update), tenant, security, chap8"
#   },
#   {
#     "category":"Environment\/Deployment",
#     "sample_values":"prdfrank (production-frankfurt), m3cemnbcf3, M3PRDUSE1B (M3 Production US-East-1 Instance B), capreprd1 (Canada production instance 1), cldops8inforos (cloud operations Infor OS), cchdevtstpp3bl, d000 (Deployment 000), d230, d811, mingleuse2 (us-east-2 region deployment)"
#   },
#   {
#     "category":"Service\/Application",
#     "sample_values":"analysissvc (Analysis Service), automationsvc, wmbatch (Batch Processing Service), migrationservice, pstools (PowerShell Tools), DocumentationCentral, kafka (Apache Kafka message streaming), service, appstream (AWS AppStream), cmw"
#   },
#   {
#     "category":"Version\/Instance",
#     "sample_values":"ssmgf35, grw10, 62, ft29, sl33, 5, wfm01, 224, i03 (Instance 03), mtmgf36"
#   },
#   {
#     "category":"Deployment Type",
#     "sample_values":"edge (Lambda@Edge), infrastructure (Infrastructure-as-Code), evergreen, aux (auxiliary), tester, deployment, updates (versioned updates), hosted (managed\/hosted service variant), dlr, patch (patch-level deployment)"
#   },
#   {
#     "category":"Function Purpose",
#     "sample_values":"secret (secret\/credential management), secret (secrets management), creation, add-or-update (Add or Update Operation), file, validate-target-group-health, status check, bootstrap, oauthkeys (OAuth keys management), routes"
#   },
#   {
#     "category":"Version",
#     "sample_values":"60, 69, 104, 77, 194, 10ionce, 74, sxe24, 2025-04, 11-4-8"
#   },
#   {
#     "category":"Functional Purpose",
#     "sample_values":"stats, log-uploader, authentication-token-validator, ip-check, vault, secret (secrets management), eecleanup (cleanup operation), oauthkeys (OAuth Keys Management), subscriber, traces"
#   },
#   {
#     "category":"Product\/Service",
#     "sample_values":"ieg, pod, mtmgf (Mongoose TMGF product), LCLSP, tamb, err, bv, m3dmp (m3=Product, dmp=Data Management Platform), idf, btm (Business Transaction Management)"
#   },
#   {
#     "category":"Node Identifier",
#     "sample_values":"l (node designation), z, s, k, g, g (Node), g (Cluster Node), f (cluster node), j (SQL Node Name), b (SQL cluster node B)"
#   },
#   {
#     "category":"Team",
#     "sample_values":"infra (Infrastructure), dma (DMA), ferry, michelinaestdev, hanover-utils, mtmgf, dma (DMA Team), dma (Data Management Automation), lkh, dte"
#   },
#   {
#     "category":"Deployment Date",
#     "sample_values":"20250825 (August 25, 2025), 250723 (July 23, 2025), 2025-06, 02 (Month), 20251011 (October 11, 2025), 241226 (2024-12-26), 2023-07, 20250820, 251016 (October 16, 2025), 20250825 (2025-08-25)"
#   },
#   {
#     "category":"Version\/Iteration",
#     "sample_values":"45, 134, 112, 71, ft13, 16ionce (version 16), 276, 54, 279, t20 (test\/template version 20)"
#   },
#   {
#     "category":"Deployment\/Region",
#     "sample_values":"prdfrank (Production-Frankfurt), wrcprd, usea1ddeb (US-EAST-1 deployment batch), mingleuse2 (us-east-2 region variant), 3851apac1 (Asia-Pacific region deployment), usea1ddeb (US-East-1 deployment), mingleeu1 (Europe Region 1 Deployment), mingleuse2 (mingle-us-east-2), mingleew2 (EU-West-2 deployment), apne1 (Asia Pacific Northeast 1)"
#   },
#   {
#     "category":"Deployment Stage",
#     "sample_values":"st (staging\/state), testbuild, postiprod (post-production), grey, PP1 (Pre-Production-1), cts, BTMSANITY (sanity test phase), play, tst, p01"
#   },
#   {
#     "category":"Region\/Environment",
#     "sample_values":"paiuse2 (US East 2), reg, cqause1 (US East 1 region), mgeuwest2 (Managed EU-West-2), m3xddedevuse1a (US-East-1a, DEV), minglene1 (ap-northeast-1), paiuse1 (Platform Instance US-East-1), cpsuse1 (ColemanPaaS US-East-1), apne1prda (Asia Pacific Northeast 1 - Production), prdapse2 (production, ap-southeast-2)"
#   },
#   {
#     "category":"Release\/Version",
#     "sample_values":"04 (Month), 02 (February), t20, pre2 (Pre-release version 2), 2024-10 (Year-Month), beta2 (beta 2 release stage), rc2 (Release Candidate 2), 16ionce, 10 (October\/month), 2025-07 (July 2025)"
#   },
#   {
#     "category":"Functionality",
#     "sample_values":"tracing (distributed tracing), tagging, tag, secret (credential\/secret management), s3backups (Amazon S3 Backups), tag (tagging\/resource tags), budget, bearer token (authentication mechanism), secret (Secrets Management), oauthkeys (OAuth key management)"
#   },
#   {
#     "category":"Environment\/Version",
#     "sample_values":"22dev, xtemp, t20 (tier 20\/test version 20), ax2, t02 (Test Environment, Version 2), sxe95, main (primary\/production branch), sxe28 (version 28), t20 (Test environment v20), x03"
#   },
#   {
#     "category":"Environment\/Location",
#     "sample_values":"se2, amcprd, stpauldev (St. Paul Development), prdfrank (production, Frankfurt region), lclsp, chslitst, dde (Data Development Environment), cismtdevuse1 (cismt development US-East-1), daldev4 (Dallas development instance 4), minglene1"
#   },
#   {
#     "category":"Functional Component",
#     "sample_values":"configurator, version, validator, bridge, exec (execution), oauthkeys (OAuth key management), tenantconfigsettings, aux (auxiliary), configure, waf (Web Application Firewall)"
#   },
#   {
#     "category":"AWS Region",
#     "sample_values":"euw2 (eu-west-2 - Ireland), usw2 (US-West-2), minglese1 (ap-southeast-1), eu-west-1, se2 (Southeast 2), ap-northeast-1 (Asia-Pacific Northeast), ap-northeast-1 (Asia Pacific - Northeast 1 \/ Tokyo), use1 (US-EAST-1), usw1 (us-west-1), minglene1 (ap-northeast-1)"
#   },
#   {
#     "category":"Application\/Module",
#     "sample_values":"maint (Maintenance), ionce, select, integration, M3SUPPORT, aux (auxiliary), wfm, common, pbcutil, mfaclient (Multi-Factor Authentication client)"
#   },
#   {
#     "category":"Application\/Cluster",
#     "sample_values":"birstappstg12 (Birst App Staging Cluster 12), birstapp139 (Birst Application cluster 139), birstapp501, sqlappprdaps1 (SQL App Production Asia-Pacific Southeast 1), birstapp156, birstapp151 (Birst Application Cluster 151), birstapp04, birstapp513, birstapp159, birstapp185 (Birst application cluster 185)"
#   },
#   {
#     "category":"Deployment Version",
#     "sample_values":"16ionce, x05 (Version\/Iteration 5), 2999, anayak, 1, ce01095, updates, ssmgf38, 2022-10 (October 2022), mingle12b"
#   },
#   {
#     "category":"Product",
#     "sample_values":"WEP, dis, coleman, dlr, colemanpaas, gtnod1b, sra, str (Infor STR Product), tamb, idc (IDC)"
#   },
#   {
#     "category":"Application\/Workload",
#     "sample_values":"sqlscratch (SQL scratch\/temporary storage), datasync, auroraload, dotnetmain, automation, processor, waflogs (Web Application Firewall logs), strtest, wmbatch, maintenance"
#   },
#   {
#     "category":"Operation Type",
#     "sample_values":"status, rotation, patch, ops (operations), deregister, inference, priority-update, push, cleanup, migrate (data\/system migration)"
#   },
#   {
#     "category":"Component Type",
#     "sample_values":"webui (Web User Interface), be (backend), common (shared library), connector, extension, utl (utility), agent, factory, core, services"
#   },
#   {
#     "category":"System\/Application",
#     "sample_values":"m3dmptst (M3 DMP Test), m3dmpcm3critfixc (M3 Data Management Platform - Critical Fix Component), wfmauto, dbshare, oslawprd, ingallsprd, m3dmpcm3xprduse1b, dmp, ihcprod, csd"
#   },
#   {
#     "category":"Deployment Time",
#     "sample_values":"052540, 075945 (07:59:45 UTC), 061847, 103235 (10:32:35 UTC), 105446 (10:54:46), 1740 (17:40 UTC), 030341, 142011 (14:20:11 UTC), 2201 (22:01 UTC), 2231 (22:31 UTC)"
#   },
#   {
#     "category":"Resource Instance",
#     "sample_values":"BI01 (Business Intelligence Instance 01), o (SQL cluster node identifier), 05, a (Node Identifier), c (node identifier), k (SQL node designation), o (SQL cluster node), a (node variant), d, sce01"
#   },
#   {
#     "category":"Application Component",
#     "sample_values":"fgt, advrep, be (backend), aux (auxiliary), apiserver, ui (User Interface tier), windsor, dotnetmain (.NET main), webui (web user interface), webui (Web User Interface)"
#   },
#   {
#     "category":"Service\/Resource Type",
#     "sample_values":"api, appstream (AWS AppStream), ecs-cluster (ECS - Elastic Container Service), datacatalog, wafv2 (AWS WAF v2 - Web Application Firewall), iam (Identity and Access Management), redis (Redis in-memory data store), s3 (Amazon Simple Storage Service), redis (Redis Cache via ElastiCache), autoscaling-group"
#   },
#   {
#     "category":"Application\/Function Purpose",
#     "sample_values":"create-key-pair, check, install, waitforinstancestatus (waits for EC2 instance status), start-stop (start and stop functionality), optimizer, create-delete, status-report, baseline, start-stop-services (Lambda function to manage service lifecycle)"
#   },
#   {
#     "category":"Deployment Environment",
#     "sample_values":"dc38 (data center 38), mgupgrade, mingleuse2, minglese1 (Southeast Asia Region 1), farm4, dde, green (Blue-Green Deployment - Active), ddelu, dmpdevuse1 (DMP Dev US-East-1), incloud"
#   },
#   {
#     "category":"Environment\/Deployment Target",
#     "sample_values":"obsdev, ATTTEST, cchmt110hammer, saudilimeprod (Saudi Arabia Lime Production), cocprd (production), sxe26, sun, wajaxprd, igwprd (IGW Production), mgqasvr22 (QA Server Farm 22)"
#   },
#   {
#     "category":"Deployment Strategy",
#     "sample_values":"scp, green (Blue-green deployment - active instance), alternating (alternating rotation strategy), evergreen, green (active deployment in blue-green strategy), blue (Blue-Green Deployment), green (Blue-Green active deployment), green (Blue-Green deployment slot), green (active deployment variant in blue-green deployment), blue (blue-green deployment - active instance)"
#   },
#   {
#     "category":"Environment\/Farm",
#     "sample_values":"mgtest25, usea1xdda (US-EAST-1 farm: xdda), pwmvf2, lspuseast, mcedev58 (development farm), mgtrain19, e, mcedev56, mcedev1eu (Managed Cloud Environment - Development 1 - Europe), ssmgfprd (ssmgf production farm)"
#   },
#   {
#     "category":"Function\/Operation",
#     "sample_values":"listner (event listener), start-stop (Start\/Stop Operations), updatesc (updates component), import, push-checks (data push validation\/checks operation), process (data processing workflow), start-stop (service lifecycle management), unsub (unsubscribe), createEndpoint, upgrade"
#   },
#   {
#     "category":"Deployment Scope",
#     "sample_values":"public (internet-facing), ALL (all targets\/regions), secondary, secret, tenant (multi-tenant), additional, product, feature, common (shared infrastructure), chs"
#   },
#   {
#     "category":"Service\/Module",
#     "sample_values":"mw, pmw, lmg (Logical Module Group), wfmpf (Workforce Management Platform Function), shredderlmg, query, lineplan, wmexcel (Warehouse Management Excel module), bluedrop, analysislmg (Analysis Lambda Monitoring Group)"
#   },
#   {
#     "category":"Deployment Configuration",
#     "sample_values":"mc (multi-cluster), coramaetrn, ae, logging, replica1 (Database Replica), reg (regional), cchcchdevtstpp8 (development-test-production phase 8), sthybrid (staging hybrid), grid (Grid topology configuration), secret"
#   },
#   {
#     "category":"Application\/Feature",
#     "sample_values":"addendpoints (add endpoints functionality), addendpoints, gifts, csfeatures (Customer-Specific Features), windsor, cloning, transactions, autoheal (auto-healing), AsyncDocumentOCR (Asynchronous Document Optical Character Recognition), coredump"
#   },
#   {
#     "category":"System\/Cluster",
#     "sample_values":"xmdev05, bi57 (Business Intelligence cluster 57), ionapi83, sclawprod, hms25, tam44 (TAM cluster instance 44), pcs1, mingle102, mc2, tam152"
#   },
#   {
#     "category":"Customer\/Tenant",
#     "sample_values":"taylorbins, GILLETTECHILDREN, vodafone, safewaydem, unitedtexasprd (United Texas Production), aaflprd, wellspanprod, lubdprd, tpsprd-sun, intersnackax1"
#   },
#   {
#     "category":"Deployment ID",
#     "sample_values":"cchf28vle2kq6lyzheeprd, LP627QATE3YHCRJB, iad01, cchka5kk339q5vwc32eprd, c2411522076753, usea1ddeb, meyn, LWM6NE343EX8TBR7, ccht78zlxa9vzjmeu9pprdgr, fondiumaeprd"
#   },
#   {
#     "category":"Resource Function",
#     "sample_values":"reformatter, generate, utility, serviceconfig, storage, deployer (deployment automation), cache, collector (data collector agent), file, userdata"
#   },
#   {
#     "category":"Instance Identifier",
#     "sample_values":"e (node instance letter), e (node instance identifier), 03, app103, 101, client2, 001, 6, 24ionce, OP01"
#   },
#   {
#     "category":"Service\/Technology",
#     "sample_values":"IAM (Identity and Access Management), wafv2 (AWS WAF v2 - Web Application Firewall), eks (EKS - Elastic Kubernetes Service), opensearch (AWS OpenSearch service), powershelltools, TextractOCR (AWS Textract Optical Character Recognition), redis (Redis cache\/data store), powershelltools (PowerShell Tools SDK), opensearch (AWS OpenSearch), msk (Managed Streaming for Apache Kafka)"
#   },
#   {
#     "category":"System\/Component",
#     "sample_values":"legacydv (legacy data vault), tms (Task\/Transaction Management System), tenor, extns (extensions), buildinfra, keystone, dbshare (database sharing service), systemdbpf, dde, dbshare"
#   },
#   {
#     "category":"Operation",
#     "sample_values":"stop, powerdown (infrastructure shutdown), purge, create (resource creation operation), result, restore, finalize, apply (configuration application action), capacity, read"
#   },
#   {
#     "category":"Resource Type\/Function",
#     "sample_values":"notification, dmp (Data Management Platform), key (TLS Key management), tenantconfigsettings, cache, ndf, ingress, redismaintenance (Redis maintenance operation), df (data-forwarder), synthetic (Synthetic Monitoring)"
#   },
#   {
#     "category":"Deployment Phase",
#     "sample_values":"pre (pre-deployment\/preliminary), init (Initialization), postuplift (post-upgrade), publish, secret, pbcrel (pre-blue-release), post-deployment, postuplift (post-upgrade state), PP1 (Pre-Production 1), p01"
#   },
#   {
#     "category":"Component\/Module",
#     "sample_values":"paisley, dde, mfaclient (MFA Client - Multi-Factor Authentication), nc (NotificationCenter), extension, mfaclient (MFA Client), cookbook, lclsp (LCLSP plugin), opera, regency"
#   },
#   {
#     "category":"System\/Module",
#     "sample_values":"sun (System Identifier), iobox, grc, wfmsecinc (WFM Security Incident module), sehtrn, m3 (M3 ERP), epm (Enterprise Performance Management), ifs (Infor Financial Suite), wfmsecinc, idmcore (IDM Core module)"
#   },
#   {
#     "category":"System Identifier",
#     "sample_values":"cchz4zu6y4dagubs83ttrn, cchdocusignincprduse1 (cch-docusign-inc-prd-use1), cchxvbumd9qfmgkxe33trn (CoreSystemId), cchlnwahhwgfvptlcgwprd (Core System ID), cchfnrldf535gq7j3fftrn, cchzv4aqm5rfqxzhghstrn, cchhv6jf7q9gtkbcurytrn (CoreSystemId), cchzv4aqm5rfqxzhghsprd (Core System ID), cchukg2vcuhq93xgyyytst, sun"
#   },
#   {
#     "category":"Team\/Business-Unit",
#     "sample_values":"ihcdev, millertrn, ferraritrn, dma (Data Management Alliance), nhldev, SRA (Shared Resource Architecture), btm, warnerdev (Warner development), ae (AE - Business Unit), mt (Monitoring Team)"
#   },
#   {
#     "category":"Environment\/Variant",
#     "sample_values":"intersndv, hf, cchdevtsttrnbl (dev\/test variant), dde, x03 (version\/variant 03), t20, delta, warrstg, gapdv, 24gov (government variant)"
#   },
#   {
#     "category":"System\/Cluster Name",
#     "sample_values":"tam68, iapidmsprf02, jdutil14, tam81, hms39, hrsdpocdev02, ionapi57, hrsdpp03, sl79, tamdev14"
#   },
#   {
#     "category":"System\/Environment",
#     "sample_values":"m3cqa, m3dmpcm3xprdeuc1 (M3 DMP Production EU Central 1), cchchomptrnuse1, actslifedev, birstdev (Birst development environment), compassgerprod (Compass Germany Production), chsdev, dde (Data Development Environment), actslifedev (Acts Lifecycle Development), ssmgf2"
#   },
#   {
#     "category":"Function Type",
#     "sample_values":"extractor, utility (utility\/supporting function), scr, synthetic (synthetic monitoring), source (data source), api, maint (maintenance), check (Health\/Status Check), collector, background"
#   },
#   {
#     "category":"Environment\/Deployment Stage",
#     "sample_values":"ddeiso, ST (System Test), ionapit2vsvc (ION API Test environment), gogdev, blue (Blue-Green Deployment - Active), preuplift (pre-uplift), dojcsstg, uhtst, ldt, xcqa"
#   },
#   {
#     "category":"Environment and Region",
#     "sample_values":"apse2prda (Asia Pacific Southeast 2 - Production A), preprdeu1 (pre-production EU region 1), prdapse2 (Production, ap-southeast-2 region), preprdeu1 (pre-production Europe 1), prdapse1 (Production, Asia Pacific Southeast 1), prduse1 (production, US East 1), prdeuw2 (production, EU West 2), prdsing (Production-Singapore), prduse1 (Production US-East-1), prdapse1 (Production - ap-southeast-1)"
#   },
#   {
#     "category":"Version\/Build",
#     "sample_values":"ce01091, ce01096, 312, mingle12b (version 12b), 284, 314, CB01, ce01083, 186, ce01082"
#   },
#   {
#     "category":"Resource\/Cluster Name",
#     "sample_values":"sl77 (SQL Cluster), ionapi95, mahinic01, megskw01, ionapi61, birstcqa303 (SQL Cluster), ionstgup06, zctst101425a, sql2609, win22dde3 (SQL Cluster)"
#   },
#   {
#     "category":"Deployment State",
#     "sample_values":"green (blue-green deployment - active), green (deployment variant), green (active\/current), green (Blue-Green Active), green (active\/current version), green (blue-green deployment active), green (active\/production deployment), green (active\/healthy deployment), blue (Blue-Green Deployment State), green (blue-green deployment slot)"
#   },
#   {
#     "category":"Operation\/Function",
#     "sample_values":"cleanup, clear (cleanup operation), index, convert, provision, schema, process, suspend, CreateModel, reset"
#   },
#   {
#     "category":"Environment Variant",
#     "sample_values":"uncprd (Unconfirmed Production), dde (Development\/Deployment Environment), leopcert, ms, train (Training), dev (Development), ref (reference), celprod, snbx (sandbox), alt (Alternate)"
#   },
#   {
#     "category":"Deployment\/Instance",
#     "sample_values":"24ionce, auroraload1, 3851, db21, op1, ionce, bcomber, 1, mhgprod, i03"
#   },
#   {
#     "category":"Purpose\/Function",
#     "sample_values":"waflogs (AWS WAF logs), uploader, metrics (monitoring\/observability), infra (Infrastructure monitoring), metrics (monitoring\/metrics collection), execution, integration, dump, datamigration, secret (Secrets Management)"
#   },
#   {
#     "category":"Product\/Project",
#     "sample_values":"cchlnwahhwgfvptlcgwprdgr (CCH product identifier), ire, cpq (Configure Price Quote), scpt, pjm (Project Job Management), gtnod1b, ssmgf, mingle (namespace qualifier), colemanpaas, dmp"
#   },
#   {
#     "category":"Environment\/Deployment Instance",
#     "sample_values":"x241, cchcchdevtstpp8, minglese2, p01 (Production instance 01), ci01 (continuous integration - instance 01), cismtdev3use1, m3perfmulti01, d008, sxe202, usea1cqaa"
#   },
#   {
#     "category":"Service\/Product",
#     "sample_values":"dlr, sce (Service\/Product Code), cfs, sce (Infor SCE service), ssb, dor, ionce12 (ION Common Services version 12), ism (ISM), nc (Notification Center subsystem), ifs"
#   },
#   {
#     "category":"Deployment Timestamp",
#     "sample_values":"20250925-101421 (September 25, 2025 at 10:14:21 UTC), 20251013-060001 (October 13, 2025 at 06:00:01), 0108 (01:08 UTC), 0110 (01:10 UTC), 241217 (2024-12-17), 20250922-045416 (2025-09-22 04:54:16 UTC), 202412061422 (2024-12-06 14:22 UTC), 1158 (11:58 UTC), 20250825-064312 (2025-08-25 06:43:12), 251024 (25 October 2024)"
#   },
#   {
#     "category":"Function",
#     "sample_values":"rotation (key rotation), maintenance, start-stop (start and stop resources), tag (tagging\/metadata), tag (tagging operations), version, reg (registration), logging, tagging, maint (maintenance)"
#   },
#   {
#     "category":"Environment\/Stage",
#     "sample_values":"sec (security), dde, jastst, dem, TST (testing stage), rcqa, tst (test), TST (test), prepost (pre-production\/post-production), cts"
#   },
#   {
#     "category":"Node\/Instance Identifier",
#     "sample_values":"q (Node Q), a, f (Node F), h (cluster node identifier), h (Node H), h, m (cluster node), i (SQL node identifier), g (SQL cluster node), b (SQL Node Identifier)"
#   },
#   {
#     "category":"Resource Name",
#     "sample_values":"ionapi69, jobsb01, ionapi11, ionapi49 (SQL Cluster Name), checksb02 (SQL Cluster Name), ionapi71 (SQL Cluster Name), ionapi59, configuration-table, db (database), cchchomptrnbl"
#   },
#   {
#     "category":"Service Component",
#     "sample_values":"cskruntimesvc (CSK Runtime Service), collector, ssf, schedulersrv (scheduler service), provision, ping, grid, be (backend), cp, elb (Elastic Load Balancer)"
#   },
#   {
#     "category":"Resource Scope",
#     "sample_values":"iam (Identity and Access Management), infra (Infrastructure), common (shared\/common resource), infra (infrastructure), set, shared, idle, table, dbinstances (database instances), common (shared\/centralized resource)"
#   },
#   {
#     "category":"Unique Identifier",
#     "sample_values":"12wnup, c4968919430054, c1720139703807 (Tenant instance identifier), c1321796228178, c4587891661144, cchxvbumd9qfmgkxe33prdbl, cchz4zu6y4dagubs83ttrngr, c2443477772762, c764299930234, cchzv4aqm5rfqxzhghsprdbl"
#   },
#   {
#     "category":"Deployment Purpose",
#     "sample_values":"implementation, source (AMI Source\/Template), reindex (OpenSearch index rebuild operation), setup, integration, policy (IAM Policy), policy, tenantprov (tenant provisioning), enable-feature-sets, sqldiff (SQL differential)"
#   },
#   {
#     "category":"Owner\/Creator",
#     "sample_values":"srayapro1 (Surya Rayaprolu - instance 1), cchcchabashax1 (Basharin instance\/deployment), wojtek (owner identifier), jkuberke (Jatin Kuberker), bsh (anatoly.basharin initials), ylin4, jhahn (User identifier), ylin4 (yin.lin), vli (owner initials), pmorlet (pierre.morlet - owner identifier)"
#   },
#   {
#     "category":"Infrastructure Component",
#     "sample_values":"intalb (internal Application Load Balancer), inforprodvms1subnet, region, intalb (internal ALB), dc, core, sf (Step Function), multiregionkms (AWS Key Management Service - multi-region), f-farm (Farm infrastructure), routes (network routing)"
#   },
#   {
#     "category":"Environment Instance",
#     "sample_values":"test9, ferry, 14ionce, 11abhinav, ihiprod, qa2 (Quality Assurance - Instance 2), ci01 (continuous integration instance 01), 04ionce, gpinonprod3, ci (Continuous Integration)"
#   },
#   {
#     "category":"Deployment Tier",
#     "sample_values":"web, runtime, test, idl, t20, utl (utility), basic, ctsdev, t02 (test tier 02), core"
#   },
#   {
#     "category":"Location\/Region",
#     "sample_values":"catawbatrn, law, chlprd, ln, southnassaunonprod, opkansas, winchesternew, strsuse1 (storage region US-East-1), CA01 (Canada region, instance 01), IN01"
#   },
#   {
#     "category":"Environment Stage",
#     "sample_values":"p01 (production 01), stg2 (staging 2), sandbox, preprd (pre-production), cqa3 (Continuous QA 3), TST (test), aqa (Automated Quality Assurance), qa1 (QA\/Quality Assurance), cqa (Continuous QA), purple"
#   },
#   {
#     "category":"Region\/Deployment Location",
#     "sample_values":"use1 (US East 1), mingleew2 (eu-west-2 region), euce1 (EU-Central-1), minglene1 (ap-northeast-1), euce1xpdb, mingleeu1 (Mingle EU Region 1), se1 (Southeast Asia 1), eu1 (Europe Region 1), mguseast (managed US East), usea1dded (us-east-1 region)"
#   },
#   {
#     "category":"AWS Service",
#     "sample_values":"lambda (Serverless Compute), s3 (Amazon S3), lambda (Lambda Serverless Compute), TextractOCR (AWS Textract-based OCR), lambda (AWS Lambda - serverless compute), fsx (AWS FSx - File System), dlm (Data Lifecycle Management), kinesis (AWS Kinesis data streaming), asg (Auto Scaling Group), TextractOCR (Textract Optical Character Recognition)"
#   },
#   {
#     "category":"Environment\/Tier",
#     "sample_values":"t03 (test tier 03), comm (communication), t01 (tier 01), t20, prime (primary\/production tier), t, product, integration, prd (Production), a"
#   },
#   {
#     "category":"Component",
#     "sample_values":"admin, apca, coreinfralmg (core infrastructure - LMG), pcm, ifs, han, webui (Web User Interface), shredderlmg (Shredder service for LMG), ifb, emscritfixc"
#   },
#   {
#     "category":"Deployment\/Version",
#     "sample_values":"24gov, t20 (Tier\/Version 20), 11upgr (version 11 upgrade), mtmgf18, mingle12f (Deployment Instance), 10ionce, 1, anayak, 14, 24ionce"
#   },
#   {
#     "category":"Resource Role",
#     "sample_values":"witness (database witness\/failover node), witness (Database Witness Server), witness (MSSQL Witness\/Mirroring Role), witness (Database Mirroring Witness), witness (Database Witness Role), witness (Database Witness), witness (Database Witness\/Mirror), witness (database witness\/mirror role), endpoint, witness (SQL Server quorum witness)"
#   },
#   {
#     "category":"Workload Type",
#     "sample_values":"SQL (database), api, cleanup task, cleanup, background (background job), maint (maintenance), schedule, load, dockersimtrans (Docker containerized simulated transactions), dockersimtrans (Docker-based simulated transactions)"
#   },
#   {
#     "category":"Application Function",
#     "sample_values":"start (start capability), patcher, job, login-check, init (initialization), updatepubsub (update publish-subscribe), start-stop (Start\/Stop Operations), secrets, status-tracker, push"
#   },
#   {
#     "category":"System\/Product",
#     "sample_values":"LAWSONBETA (Lawson Beta), INFORBCREP01 (Infor Business Central Reporting), lawson (Infor Lawson ERP), stlawson (Sumo to Lawson), m3 (Infor M3 ERP system), cpsuse1 (Coleman PaaS US-East-1), rhythm, dis (Data Ingestion Services), hms, SAMS"
#   },
#   {
#     "category":"Resource Designation",
#     "sample_values":"m (Node identifier), h (Node identifier), allocation, d (Node identifier), o (SQL cluster node designation), d (node designation), common (shared resource), r (Replica\/Node), topic (Kafka topic), d (Data volume designation)"
#   },
#   {
#     "category":"Application\/Project",
#     "sample_values":"hanover, cpq (CPQ - Configure Price Quote), monocle, lms (Learning Management System), erpsl, qna, mingle88 (Mingle product, cluster 88), mingle (Product), birstapp, mrm"
#   },
#   {
#     "category":"Team\/Owner",
#     "sample_values":"jkuberke (Developer identifier), prashant, yyu (yice.yu), eiclawson, simonsdev, narbudt, ccolvin01 (user\/owner identifier), kur (team identifier), michelinaetst, spenmetsa (Penmetsa - resource owner)"
#   },
#   {
#     "category":"Instance\/Version",
#     "sample_values":"LM01, sxe201, sxe84, sxe19, 1, 05, i03 (Instance 03), i03, LS01, 9"
#   },
#   {
#     "category":"Version\/Variant",
#     "sample_values":"x02 (variant 2), sxe86, m3, ln3, vli2, base (baseline\/base configuration), m306ionce, minglese2, ax3, ssmgfiso"
#   },
#   {
#     "category":"Deployment Status",
#     "sample_values":"rollback, green (Blue-Green deployment - active), rename (Migration\/Rename Operation), green (Blue-Green Active Deployment), postuplift (post-migration\/upgrade), green (blue-green deployment - active\/target), green (active\/production deployment), green (Active\/Current Deployment), green (Blue-Green Active), green (blue-green active deployment)"
#   },
#   {
#     "category":"Owner",
#     "sample_values":"jshan (jeff.shan@infor.com), pmorlet (Pierre Morlet), tonyw (tony.wang), bcushman (bert.cushman - resource owner), lukexu, bsh (basharin), jkuberke, jcheng (Jacky Cheng), dguo (David Guo), ylin (Yin Lin)"
#   },
#   {
#     "category":"Service\/Function",
#     "sample_values":"datasync, dbmwstatus, status, agent-checks, cwlogs2sumo (CloudWatch Logs to Sumo Logic), submit (workflow action), metrics-metadata-collector, auto-heal-mashup-nodes, remotemgmt (remote management), updater"
#   },
#   {
#     "category":"Environment\/Deployment Variant",
#     "sample_values":"shane, iso, storyesc, ssotest (Single Sign-On Test), prdfrank (production-frank), g, dlqpv2, xdde, green (Green deployment slot), prdsing"
#   },
#   {
#     "category":"Application\/Purpose",
#     "sample_values":"secrets, restore (database restore operation), waflogs (WAF logs - Web Application Firewall logs), deployer, feature-enablement, backup (Database Backup), creation, sqldiff (SQL Differential Backup), push-checks, waflogs (Web Application Firewall logs)"
#   },
#   {
#     "category":"Deployment Context",
#     "sample_values":"maint (maintenance), mgmt (Management), integ (integration), mctx (multi-context), mctxprod (tenant\/deployment context identifier), infra, opsint (operations-integration), mode, infra (Infrastructure), xanterradev"
#   },
#   {
#     "category":"Resource Component",
#     "sample_values":"configuration-table, db (database), indexes, waf (Web Application Firewall), wmttv, routes (network routes), core, apppools (application pools), powershelltools, source (Sumologic data collection source)"
#   },
#   {
#     "category":"Release Date",
#     "sample_values":"2022-09 (year-month), 2024 (year), 2025 (year), 2022-06, 2025-06 (June 2025), 2024-10 (October 2024), 2024-01 (January 2024), 2023-01, 06 (June), 2024-07 (July 2024)"
#   },
#   {
#     "category":"Deployment\/Environment Identifier",
#     "sample_values":"m12use1b, cchuofmprduse1 (includes us-east-1 region), cchelh5vh2mbvgsmv7dprd, dnmammouchi1, regency, ctsprod, 04ionce, cchelh5vh2mbvgsmv7dprd (CoreSystemId), d101, 22wnup"
#   },
#   {
#     "category":"Operation\/Action",
#     "sample_values":"associate, ins (install), publish, powerdown, attach, ins (Installation), save, update (database upgrade operation), restart, upgrade"
#   },
#   {
#     "category":"Owner\/User",
#     "sample_values":"cwang3 (Conrad Wang - user identifier), cwang3 (Conrad Wang), gab (Gabriel Qian), yyu (yice.yu), ylin2 (Yin Lin), dguo (david.guo), ylin4 (yin.lin user identifier), ylin4 (owner: yin.lin@infor.com), ngeyer, rogier"
#   },
#   {
#     "category":"Environment\/Cluster",
#     "sample_values":"c (Cluster), jasdde, clmonitor, cchcchdevtstax4, warrsup, jrk, mingle12f, ci01 (continuous integration instance 01), cchphhstrngr, c"
#   },
#   {
#     "category":"Service Type",
#     "sample_values":"elasticsearch, platformsvc (Platform Service), collector (data collection service), webservice, hosted-collector, runner (GitLab Runner), api, lambda (AWS Lambda), source, provider"
#   },
#   {
#     "category":"Feature\/Capability",
#     "sample_values":"synonyms, flowLogs (VPC Flow Logs), geofencing (geographic access control), geofencing, autoheal (Auto-healing), lifecycling (S3 Lifecycle Management), secret (secret rotation), geolocation (geographic location-based routing), autoheal (Automatic Healing), AsyncDocumentOCR"
#   },
#   {
#     "category":"Customer\/Environment",
#     "sample_values":"pennsthealthtst (Pennsylvania Health - Test environment), burtoncoprod, ninaprd-sun (Customer environment identifier), mmpcprod, safewaytst (Safeway Test), swarovskiprod (Swarovski Production), cchpennstatehealthprd (Penn State Health Production), ncbaprd-sun, oaksprd-sun (customer prefix), Intersnackprod (Intersnack production)"
#   },
#   {
#     "category":"Environment\/Target",
#     "sample_values":"warrstg (WAR Staging), ibminonprod2 (IBM non-production environment 2), trn, mguseastb (Managed US-East Region - Target B), intersnackprep, warnertest (test environment), phsatrn, mccarthytrn, crmt2vpoc, p01 (partition\/pod 01)"
#   },
#   {
#     "category":"Service\/Tool",
#     "sample_values":"sumoIns (Sumo Logic Installation), sumologic (Monitoring\/Logging Platform), GitLab, Telegraf (metrics collection agent), gitlab (GitLab CI\/CD platform), sumologic (Sumologic monitoring service), telegraf (metrics collection tool), telegraf (Telegraf metrics agent), telegraf (InfluxData metrics collection agent), scanner"
#   },
#   {
#     "category":"Deployment\/Instance Identifier",
#     "sample_values":"usea1cqaa, leopprd2019, i03 (instance 03), 3851, lemur, frep25p8, usea1ddec (us-east-1 deployment instance), m12use1b (release m12, US-East-1 region, instance b), usea1ddeb (US-East region deployment instance), 24ionce"
#   },
#   {
#     "category":"Environment\/Account",
#     "sample_values":"umpprd, stcs, cfs (account identifier), sctqac, cchbaycarehstrn, nutacpt, cismt, mgmcprod, wencorprod (WEN corporate production account\/region), cchphhsprdbl"
#   },
#   {
#     "category":"System Component",
#     "sample_values":"mrks, ipf, engine, dlr, infra (infrastructure), trn, ionce, cg, icb, mec"
#   },
#   {
#     "category":"Capability",
#     "sample_values":"sso (Single Sign-On), apianalytics (API Analytics), stop, upload, assume (role assumption), inference, secret (secrets management), configure, secret (rotation), cloning"
#   },
#   {
#     "category":"Resource Type\/Purpose",
#     "sample_values":"elblogs (Elastic Load Balancer logs), datawarehouse, executionrole (Lambda execution role), serviceconf (service configuration), waflogs (Web Application Firewall logs), secret (Secrets Management), utl (utility), config (configuration), secret (Secrets Manager\/rotation), monitor (CloudWatch monitoring\/observability)"
#   },
#   {
#     "category":"Customer\/Client",
#     "sample_values":"deloitte (Deloitte), Delfingen, 04ionce, rabobankprd (Rabobank Production), scotiabank, albertsonsqa (Albertsons QA), Disney, safinvestp-sun, pennstatehealth, rabobankprd (Rabobank)"
#   },
#   {
#     "category":"Business Unit",
#     "sample_values":"mgm, koch, tam, mcc, bv, cts, adopter, pa, grc (Global Risk and Compliance), adopters (customer segment)"
#   },
#   {
#     "category":"Deployment Model",
#     "sample_values":"PaaS (Platform-as-a-Service), tenant (multi-tenant), saas (SaaS - Software-as-a-Service), Tenant (multi-tenant), shared, adopters (Multi-tenant), Tenant, per-tenant (multi-tenant), hosted (hosted\/managed service variant), hosted (managed\/hosted deployment)"
#   },
#   {
#     "category":"Infrastructure\/Region",
#     "sample_values":"mgeuwest2 (eu-west-2), AD (Availability Domain), aapcprd (Asia-Pacific Production), st, phsprd, seuc1 (South Europe UC - Instance 1), norcrosaeprd, mgapse2 (AWS ap-southeast-2), becisprd, mgeuwest2 (Mongoose EU-West-2)"
#   },
#   {
#     "category":"Cluster Name",
#     "sample_values":"birstdev08, m377, zcwin22up2, n1023, ionapi28, sl31, sl40, tamibinb21022, ionapi65, tam105"
#   },
#   {
#     "category":"Identifier",
#     "sample_values":"cchelh5vh2mbvgsmv7dtrngr, c778403152141, SUN, emscritfixb, 08ionce, law, c7415133670660 (tenant instance unique identifier), O19CSB1011, 3011, c4109014351925 (Deployment\/Account identifier)"
#   },
#   {
#     "category":"Capability\/Function",
#     "sample_values":"publish, publisher, decryption, oauthkeys (OAuth key management), validation, tracing (Distributed Tracing), apikey-generator, upload, render, start-stop"
#   },
#   {
#     "category":"Platform",
#     "sample_values":"mssql (Microsoft SQL Server), INCLOUD (Infor Cloud), lmrk (Landmark), ion (Infor ION), ipi, ION (Infor's integration platform), os (InforOS), ION (Infor Operating Network), windows, AWS (Amazon Web Services)"
#   },
#   {
#     "category":"Module\/Component",
#     "sample_values":"regency, acm, configure, pmw, lmg, btm, analysislmg (Analysis LMG), cmc, ionce, SCM1 (Supply Chain Management Module)"
#   },
#   {
#     "category":"Application\/Functionality",
#     "sample_values":"feature-toggle-update, triage, login (login monitoring), site, oauthkeys, file-upload (file upload functionality), start-stop (start and stop capabilities), start-stop (start and stop operations), events, push"
#   },
#   {
#     "category":"Tenant\/Customer",
#     "sample_values":"luminartrn, oldnavytst, yoteltst, cchpennstatehealthprd, mclarentrn, twlh5, cchanthcprd, COSPRD, becklawsonprod, fnrldf535gq7j3fftrn"
#   },
#   {
#     "category":"Environment Tier",
#     "sample_values":"common, qa2 (QA environment, instance 2), developer, PP3 (Pre-Production 3), TST (test), TST (Test), PP1 (Pre-Production 1), aqa (Automated Quality Assurance), developer (developer tier), prd (Production)"
#   },
#   {
#     "category":"Instance\/Identifier",
#     "sample_values":"cace1 (unique instance identifier), 24ionce, 111, 01 (instance number), 625, mua, CB01, 14ionce, sxe204, x204"
#   },
#   {
#     "category":"System\/Instance",
#     "sample_values":"nhrmcprod, INFORBCAD01, m3perfdev01 (M3 product, performance development environment, instance 01), ionce, rrdman01, isprep01 (IS Preparation Instance 01), xmdev02 (XM product, development instance 02), compassprd, cammchprd, m3cemnbcf2"
#   },
#   {
#     "category":"Version\/Environment",
#     "sample_values":"mingle12f, report25p6, sxe26, q, 10, sxe20, sxe81, t20 (test environment, version 20), sxe17, sl70 (Syteline v70)"
#   },
#   {
#     "category":"Infrastructure\/Farm",
#     "sample_values":"mcvmd71, mguseastb (managed group, US East region), lspeucentb (EU Central Farm B), mguseast, mguseast1 (managed group US East 1), mgtstbmn1, saaspf (SaaS Platform Farm), mgiso, lspuseast (US East farm), mgiso (farm\/infrastructure location)"
#   },
#   {
#     "category":"Deployment Slot",
#     "sample_values":"blue (blue-green deployment slot), green (active deployment), green (Blue-green deployment active slot), blue (Blue-green deployment slot), green (deployment slot), green (Blue-Green Deployment Active Slot), green (Green deployment slot, indicating active\/production variant), green (blue-green deployment active slot), blue (Blue-Green Deployment Slot), green (Blue-Green Active Deployment)"
#   },
#   {
#     "category":"Application\/Function Type",
#     "sample_values":"ref (reference\/rotation function), source, forwarder, parser, synthetic (synthetic monitoring), source (data source integration), synthetic-checks (synthetic monitoring checks), collector, scan, checks"
#   },
#   {
#     "category":"Owner\/Developer",
#     "sample_values":"pmorlet (Pierre Morlet), jessdev (Jesse Evans - Developer), anayak (Ashis Nayak - Resource Owner), roy04 (developer identifier), pedro, ylin2, jshan, bsh (anatoly basharin), jkuberke (jatin.kuberker), roy04 (roy.xia)"
#   },
#   {
#     "category":"Architecture Pattern",
# ...
#   },
#   {
#     "category":"Database Node",
#     "sample_values":"j, c, h, l, m (SQL Node Identifier), k, w, o"
#   },
#   {
#     "category":"Resource Instance\/Node Identifier",
#     "sample_values":"e, j, a (Node A), f, o (Node O), f (Cluster Node F), j (node identifier), g (SQL Node identifier)"
#   },
#   {
#     "category":"Geographic Location",
#     "sample_values":"mguseast, sydney, sydney (Sydney, Australia), frankfurt, romania (Romania region), malaysia, mingleeu1 (EU Region 1), sydney01 (Sydney region, instance 01)"
#   },
#   {
#     "category":"Check Type",
#     "sample_values":"ReportingCheck, functionality, LoginCheck, IPFBasicCheck (basic health check), CSILoginCheck, health, DBSchemaCheck (Database Schema Check), FTKLoginCheck (FT K Login Check)"
#   },
#   {
#     "category":"Deployment Environment\/Region",
#     "sample_values":"mingleca1 (Mingle Canada Region 1), minglene1 (Mingle Northeast-1), inteuc1 (integration-eu-central-1), ddelu, mingleca1 (Mingle Canada Central 1), prdeuc1 (prd=production, euc1=EU Central 1 region), minglene1 (Asia Pacific Northeast 1 region)"
#   },
#   {
#     "category":"Service Layer",
#     "sample_values":"aps (Application Platform Server), web, web (web tier), core (Core\/Central component), srv (Server), ido (Integration Data Object), proxy"
#   },
#   {
#     "category":"Instance\/Node",
#     "sample_values":"e, FS01, a (Node A), i, LM01, j (Node identifier), a"
#   },
#   {
#     "category":"Deployment Classification",
#     "sample_values":"integration, infrastructure, common, adopter, common (shared\/common resource), iso, product"
#   },
#   {
#     "category":"Environment and Location",
#     "sample_values":"prdfrank (production Frankfurt), prdcac1 (Production - ca-central-1), prdfrank (production - Frankfurt), prdsyd (production-Sydney), prdfrank (Production-Frankfurt), prdsyd (Production-Sydney), prdcac1 (production, ca-central-1)"
#   },
#   {
#     "category":"Deployment Target\/Environment",
#     "sample_values":"minglese2 (Mingle Southeast 2 region - ap-southeast-2), cchpennstatehealthtrngr (Penn State Health Training), warrsup, mcc, intersndv, mingleuse2, itwwestmaprod (production deployment target)"
#   },
#   {
#     "category":"Tool\/Service",
#     "sample_values":"sumologic (Sumo Logic), sumologic (Sumo Logic monitoring), Jenkins (CI\/CD automation), sumologic, sumologic (monitoring and logging service), telegraf (metrics collection agent), gitlab"
#   },
#   {
#     "category":"Data Type\/Source",
#     "sample_values":"waflogs (WAF logs - Web Application Firewall logs), waflogs (WAF Logs - Web Application Firewall Logs), waflogs (Web Application Firewall Logs), waflogs (WAF logs), waflogs (Web Application Firewall logs), waflogs (WAF Logs - Web Application Firewall logs), waflogs (AWS WAF Logs)"
#   },
#   {
#     "category":"Resource Type\/Scope",
#     "sample_values":"infra (Infrastructure), mgm (management), infrastructure, services, infra (infrastructure), pool (resource pool), iam (IAM-scoped resource)"
#   },
#   {
#     "category":"Team\/Variant",
#     "sample_values":"pattiesdev, fpidev, mhdev, lcidev, ksfdev, dswdev, ferrari"
#   },
#   {
#     "category":"Release Identifier",
#     "sample_values":"05b, 10e, pbcrel, 08c, 10d, newrel (new release), 05c"
#   },
#   {
#     "category":"Protocol",
#     "sample_values":"http (HTTP protocol), http (Hypertext Transfer Protocol), http, http (HTTP), http (HyperText Transfer Protocol), http (HTTP Protocol), HTTP (Hypertext Transfer Protocol)"
#   },
#   {
#     "category":"Security Classification",
#     "sample_values":"owasp (OWASP Compliance), secure, secret, sec (Security), trusted, owasp (OWASP security framework), sec (security-related)"
#   },
#   {
#     "category":"Version\/Release Month",
#     "sample_values":"04, 01, 01 (January), 10 (October), 06, 07h (July), 08"
#   },
#   {
#     "category":"Target Service",
#     "sample_values":"db (database), dmp, s3 (AWS S3), ecs (Elastic Container Service), s3 (Simple Storage Service), alb (Application Load Balancer), wafv2 (AWS WAF v2)"
#   },
#   {
#     "category":"Role Purpose",
#     "sample_values":"init, TESTROLE (Test Role), init (initialization), delegaterole (delegate role), init (Initialization), execution, utility"
#   },
#   {
#     "category":"Product\/Plugin Name",
#     "sample_values":"ISR (Infor product\/plugin identifier), wep (WEP), ISR, lclsp (LCLSP), M3CE, WEP, m3ce (M3CE)"
#   },
#   {
#     "category":"Component Identifier",
#     "sample_values":"ionce, dmp, mec, cmw, sts, law, dlr"
#   },
#   {
#     "category":"Storage Technology",
#     "sample_values":"fsx (Amazon FSX), fsx (AWS FSx - File System), fsx (AWS File System), ontap (NetApp ONTAP storage technology), fsx (AWS FSx), ontap1 (NetApp ONTAP - instance 1), fsx (Amazon FSx)"
#   },
#   {
#     "category":"Change\/Ticket ID",
#     "sample_values":"MCRM-13281, mce4349, ADT577989, sre4019 (Site Reliability Engineering ticket 4019), ADT577986, PDM32904, ADT5779883"
#   },
#   {
#     "category":"Deployment\/Test Type",
#     "sample_values":"BTMSANITY (BTM Sanity Testing), BTMSANITY (BTM Sanity Test), BTMSANITY (BTM Sanity testing), BTMSANITY (sanity test deployment), BTMSANITY (sanity test), BTMSANITY (Sanity Test), BTMSANITY (Sanity Test Suite)"
#   },
#   {
#     "category":"Capability\/Purpose",
#     "sample_values":"integration, scripting, failure (failover capability), secret (secret management\/rotation), enablement, metrics, failure (failover\/disaster recovery)"
#   },
#   {
#     "category":"Product Name",
#     "sample_values":"isr (ISR), LCLSP, ISM, ism (ISM), HTIS, m3ce (M3CE), WEP"
#   },
#   {
#     "category":"Deployment\/Region Identifier",
#     "sample_values":"nutDR3, biiprd, mgmc, usea1ddee (us-east-1 region with unique instance identifier), mingleca1 (Canada central region deployment), mingleca1 (mingle-ca1 deployment), m12use1b"
#   },
#   {
#     "category":"Deployment\/Variant",
#     "sample_values":"ihiprod, ih2auto, fdhtrn, janus, regency, integ (integration), tam"
#   },
#   {
#     "category":"Deployment Initiative",
#     "sample_values":"appmigration (Application Migration Project), launch, migration, elbmig (ELB Migration), optimization, appmigration, upgrade"
#   },
#   {
#     "category":"System\/Tenant",
#     "sample_values":"inforsts, compassprd (Compass Production Tenant), twlh5, liliumedictrn, ionce, oslawtrn, constellis"
#   },
#   {
#     "category":"Service Variant",
#     "sample_values":"trn, vbsvc (service variant), hosted, dbup (Database Update), agentless, vbsvc, plus"
#   },
#   {
#     "category":"Deployment\/System",
#     "sample_values":"restart-instance-failed-status-check (automated EC2 instance restart on failed status check), dma (deployment identifier), iplprod, cchchomptrnbl (Deployment identifier), cchka5kk339q5vwc32etrn (Deployment cluster identifier), Workflow, vpc52"
#   },
#   {
#     "category":"Workload\/Module",
#     "sample_values":"work, wfmpf, reportingmodels, genreinv, wmbatch, wfmqa, M3SUPPORT (Infor M3 Support)"
#   },
#   {
#     "category":"SQL Node Identifier",
#     "sample_values":"l, f, b, c, g, d, c (Node C)"
#   },
#   {
#     "category":"Environment\/Branch",
#     "sample_values":"master (git branch), master, feature (feature branch\/environment), feature, main (primary\/main branch), main, trunk"
#   },
#   {
#     "category":"Resource Type\/Role",
#     "sample_values":"witness, subscriber, client, workers (worker compute role), app (application server), workers, witness (SQL Server Witness Node)"
#   },
#   {
#     "category":"Resource Node Identifier",
#     "sample_values":"a (Node Identifier), e (Node E), b (SQL cluster node identifier), d (Node D), l (node identifier), l (SQL cluster node l), m"
#   },
#   {
#     "category":"Environment\/Deployment ID",
#     "sample_values":"cchxvbumd9qfmgkxe33prd (production deployment identifier), mscmqasdm (QA Environment), dojcsdem, cchbwlgdhke4tzemwhtprd (unique deployment identifier), kmctest, ddee, mscmqa4sdm (QA Environment)"
#   },
#   {
#     "category":"Deployment\/Application",
#     "sample_values":"paisley, knox, se-table-modification-dem (deployment identifier for table modification Lambda function), foo-fighters, cchdocusigninctrnuse1, monocle, mingle"
#   },
#   {
#     "category":"Monitoring\/Observability",
#     "sample_values":"sumologic, metrics, newrel (New Relic), monitor, sumologic (Sumo Logic), sumologic (Sumo Logic monitoring platform), sumologic (Sumologic monitoring platform)"
#   },
#   {
#     "category":"Application\/Variant",
#     "sample_values":"adopter, ionce, vidadev, wfmhenmtdev, inpactest, net48full (.NET 4.8 Full Framework), xperf (performance testing variant)"
#   },
#   {
#     "category":"Deployment Color",
#     "sample_values":"green (blue\/green deployment), green (Blue-Green Deployment), green, blue (Blue-Green Deployment), blue, green (Active blue-green deployment variant), blue (blue-green deployment)"
#   },
#   {
#     "category":"Deployment Mechanism",
#     "sample_values":"doc (Systems Manager Document), file-based, file, asg (Auto Scaling Group), ssm (AWS Systems Manager), doc (Document), file (file-based deployment)"
#   },
#   {
#     "category":"Platform\/Environment",
#     "sample_values":"colemanpaas (Coleman PaaS), os (Infor OS), wind (Windows), colemanpaas (PaaS platform), colemanpaas (Platform-as-a-Service), colemanpaas (Coleman PaaS platform), suse1"
#   },
#   {
#     "category":"Instance\/Variant Identifier",
#     "sample_values":"j (instance variant identifier), BI01 (Business Intelligence Instance 01), k, x02, x03, a, i03"
#   },
#   {
#     "category":"Installation\/Environment",
#     "sample_values":"t20, dbobirtest, 16ionce (InstallId), mingleew2, suse1, 20ionce (InstallId), t20 (InstallId)"
#   },
#   {
#     "category":"Database Role",
#     "sample_values":"witness (Database Mirroring Witness), witness, witness (SQL Server Witness Node), witness (MSSQL Witness), witness (SQL Server Witness), witness (SQL Server Witness Instance), admin (administrative)"
#   },
#   {
#     "category":"Purpose\/Scope",
#     "sample_values":"td (Temporary Data), maint (maintenance), infrastructure, usage, test (testing), intg (Integration), automation (test automation)"
#   },
#   {
#     "category":"Application\/Functional Component",
#     "sample_values":"prepare, patchbaseline, search, integration, cspkey (consumer secret\/key), tenant-manager-grid, datalink"
#   },
#   {
#     "category":"Version\/Deployment Identifier",
#     "sample_values":"aoddv, t20, mingle12f, 04ionce, mingle12b, vli2, 11upgr (version 11 upgrade)"
#   },
#   {
#     "category":"System Type",
#     "sample_values":"systems, integration, infrastructure, infra (infrastructure), workflow, st (staging\/system test), legacyprd (Legacy Production)"
#   },
#   {
#     "category":"Environment\/Workload",
#     "sample_values":"clagent, descredstest, loadtemp, xperf, iosdev, wchndev, testscan"
#   },
#   {
#     "category":"Region\/Cluster",
#     "sample_values":"kr1, euc09 (EU-Central region, cluster 09), cac1, cpsbeuc1, m3seuc1 (cluster identifier), mohgprod, suse1 (SUSE cluster region 1)"
#   },
#   {
#     "category":"Availability Zone\/Location",
#     "sample_values":"dbaz3, dbaz2 (database availability zone 2), dbaz1, dbaz3 (database availability zone 3), be-az1 (Backend Availability Zone 1), be-az3 (backend, availability zone 3), dbaz2"
#   },
#   {
#     "category":"Purpose\/Content",
#     "sample_values":"waflogs (WAF logs), metadata, waflogs (Web Application Firewall logs), waflogs (WAF Logs), data, waflogs (AWS WAF logs), elblogs (Elastic Load Balancer logs)"
#   },
#   {
#     "category":"Organizational Unit",
#     "sample_values":"Tenant, lmg (LMG - Infor organizational unit), lmg, reg, idmdo, ornuaprd, reg (Regional)"
#   },
#   {
#     "category":"Target Resource Type",
#     "sample_values":"ec2 (Elastic Compute Cloud), appsrv (application server), appserver (application server), rds (Relational Database Service), ec2 (EC2 Instances), log-db (log database), instances (EC2 instances)"
#   },
#   {
#     "category":"Target System",
#     "sample_values":"compassprd (Compass production instance), reservecloud, constellisprd (Constellis production), os (Operating System), orbis, es (Elasticsearch), ibminonprod (IBM in non-production)"
#   },
#   {
#     "category":"Location\/Farm",
#     "sample_values":"usea1cqaa (US East 1 farm), lspeucent1, mgeucent1 (managed-group-eu-central-1), lspeucent1 (eu-central-1 farm), usea1ddek, mgcacen1 (managed Canada central region 1), usea1inta (US East 1 Infrastructure)"
#   },
#   {
#     "category":"Deployment Target\/Account",
#     "sample_values":"apllpqa, ATTPROD, bencoprd, arvestprod, bnsprod, glencoenonprod, aeatst"
#   },
#   {
#     "category":"Domain",
#     "sample_values":"ledger, grc (Governance, Risk, Compliance), mgm, budget, grc (Governance, Risk, and Compliance), cost, grc (Governance, Risk & Compliance)"
#   },
#   {
#     "category":"Identifier\/Version",
#     "sample_values":"16ionce, t20, caspn1203, 3851, 104, xxxxxxx (masked identifier), kf1"
#   },
#   {
#     "category":"Component\/Layer",
#     "sample_values":"integration, cp, api (API layer), cspagent (CSP Agent), frontend, process (processing component), meta"
#   },
#   {
#     "category":"Network Scope",
#     "sample_values":"public, private, private (private subnet), ext (external\/internet-facing), ext (external), private (Private network), private (private network infrastructure)"
#   },
#   {
#     "category":"Project\/Tenant",
#     "sample_values":"mctxtrain, mptfprod, komar, pfjtc, asrytrn (Project\/tenant identifier), twlh5, khtest"
#   },
#   {
#     "category":"Processing Type",
#     "sample_values":"async (asynchronous), stream (stream processing), event (event-driven), workflow, priority, batch, event (event-driven processing)"
#   },
#   {
#     "category":"Operation Scope",
#     "sample_values":"capacity, delta (incremental), process, window, patching, info (information\/metadata), file"
#   },
#   {
#     "category":"Application\/Service Name",
#     "sample_values":"m3dmpprdapse2 (M3 DMP Production APSE2 - Asia Pacific Southeast 2), start-stop-auth-services (start\/stop authentication services), self-service, jackdb, m3dmpprdeuc1, exportview, m3dmpcm3prepuse1"
#   },
#   {
#     "category":"Region and Environment",
#     "sample_values":"euce1prda (eu-central-1, production), apne1prda (AWS Region: ap-northeast-1, Environment: production), euce1prda (EU Central 1 Production), apse2prda (ap-southeast-2 production), usea1inta (us-east-1 integration), apse2prda (ap-southeast-2, production), usea1inta (us-east-1 integration-a)"
#   },
#   {
#     "category":"Adopter\/Customer Identifier",
#     "sample_values":"tam, m3-ems, ipi, ieg, dlr, idf, idf-idc"
#   },
#   {
#     "category":"Resource Function\/Purpose",
#     "sample_values":"billing-metrics-publisher, patcher (patch application tool), execution, oauthkeys, check-code-deployed (code deployment verification), ingress (inbound traffic\/access handler), tenantrefresh"
#   },
#   {
#     "category":"Release",
#     "sample_values":"rel202601 (Release 2026-01), 10, 205, newrel, rel (release), newrel (new release), 1"
#   },
#   {
#     "category":"Version\/Year",
#     "sample_values":"2024, 2024 (deployment year), 2023, 2020, 2025, 2021, 2026"
#   },
#   {
#     "category":"Instance\/Deployment",
#     "sample_values":"OP01, SO01, i03 (instance 03), i02 (Instance 02), i03, 01 (deployment instance), i03 (instance identifier)"
#   },
#   {
#     "category":"Deployment\/Test Phase",
#     "sample_values":"BTMSANITY (sanity testing), BTMSANITY (Sanity test phase), BTMSANITY (BTM Sanity testing phase), BTMSANITY, BTMSANITY (BTM Sanity Test), BTMSANITY (Business Transaction Management Sanity Test), BTMSANITY (BTM Sanity Testing)"
#   },
#   {
#     "category":"Resource Node",
#     "sample_values":"d, f (SQL Node Identifier), o (Node designation), e (Node E), u (node identifier), d (Node D), c (Cluster Node C)"
#   },
#   {
#     "category":"Cloud Platform",
#     "sample_values":"azure, aws (cloud platform), AWS (Amazon Web Services), aws, azure (Microsoft Azure), aws (Amazon Web Services), AWS"
#   },
#   {
#     "category":"Data Format",
#     "sample_values":"ndjson (Newline Delimited JSON), parquet, parquet (Apache Parquet columnar format), ndjson (Newline Delimited JSON format), parquet (Apache Parquet), ndjson (Newline-Delimited JSON), parquet (Apache Parquet format)"
#   }
# ]
# </all_categories>

# %%
categories = load_json(COMPONENTS_AGG_INFO_FILE)

# %%
categories[:2]
# Out:
# [{'category': 'Environment',
#   'sample_values': 'fdprod (FD Production), xprep (preparation/staging environment), bexarprod, lspeucentb (Farm), prdsing (production-staging environment), develop (development branch), PP2 (pre-production 2), m3cecritfixc (M3CE Critical Fix environment), cismt3devuse1 (development, US-East-1 region), acct (account)'},
#  {'category': 'Project/System',
#   'sample_values': 'sce (SCE product/project), cchh9cfqg3ymhauu8qqprd (unique identifier), ssmgf14 (SSMGF product cluster 14), tam93, tam178 (cluster identifier), ezrms (EZ RMS - Revenue Management System), mingleios06 (Mingle product cluster instance), str (product), rdr (RDR product), tam03'}]

# %%
dict_to_json_str(categories[0])
# Out:
# '{\n  "category": "Environment",\n  "sample_values": "fdprod (FD Production), xprep (preparation/staging environment), bexarprod, lspeucentb (Farm), prdsing (production-staging environment), develop (development branch), PP2 (pre-production 2), m3cecritfixc (M3CE Critical Fix environment), cismt3devuse1 (development, US-East-1 region), acct (account)"\n}'

# %%
from layer_1_util_modules.general_util.id_gen import generate_id

# %%
# Create batch requests in Vertex AI format
batch_requests = []

for rec in categories:
    # Format the prompt with the data
    prompt_part_2 = PROMPT_TEMPLATE_PART_2.format(specific_category=dict_to_json_str(rec))
    
    # Create the batch request item in Vertex AI format
    batch_request = {
        "custom_id": generate_id(),
        "request": {
            "anthropic_version": "vertex-2023-10-16",
            "max_tokens": 6000,
            "temperature": 0.2,
            "messages": [
                {
                    "role": "user",
                    "content": prompt_to_cache,
                    "cache_control": {"type": "ephemeral"}
                },
                {
                    "role": "user",
                    "content": prompt_part_2
                },
            ],
            "tools": [
                 {
                    "type": "custom",
                    "name": "process_category",
                    "description": "Process Category",
                    "input_schema": {
                        "type": "object",
                        "properties": {
                            "category": {
                                "type": "string",
                                "description": "The specific category being researched"
                            },
                            "most_similar_category": {
                                "type": "string",
                                "description": "The category that is most similar to the specific category being researched"
                            },
                            "should_consolidate": {
                                "type": "boolean",
                                "description": "Whether we should consolidate or not"
                            },
                            "rationale": {
                                "type": "string",
                                "description": "The rationale of whether we should consolidate or not"
                            },
                            "new_consolidated_category_name": {
                                "type": "string",
                                "description": "The new category name of the consolidated categories"
                            }
                        },
                        "required": [
                            "category",
                            "most_similar_category",
                            "should_consolidate",
                            "rationale"
                        ]
                    }
                }
            ]
        }
    }
    
    batch_requests.append(batch_request)

print(f"Created {len(batch_requests)} batch requests")
# Out:
# Created 710 batch requests

# %%
batch_requests[0]
# Out:
# {'custom_id': '2025-11-03-18-50-01-128-18180a76',
#  'request': {'anthropic_version': 'vertex-2023-10-16',
#   'max_tokens': 6000,
#   'temperature': 0.2,
#   'messages': [{'role': 'user',
#     'content': '\nYou will analyze AWS resource categories to identify potential consolidation opportunities. Your task is to determine whether a specific category should be consolidated with another similar category from a comprehensive list.\n\nHere is the complete list of all AWS resource categories:\n\n<all_categories>\n[\n  {\n    "category":"Environment",\n    "sample_values":"fdprod (FD Production), xprep (preparation\\/staging environment), bexarprod, lspeucentb (Farm), prdsing (production-staging environment), develop (development branch), PP2 (pre-production 2), m3cecritfixc (M3CE Critical Fix environment), cismt3devuse1 (development, US-East-1 region), acct (account)"\n  },\n  {\n    "category":"Project\\/System",\n    "sample_values":"sce (SCE product\\/project), cchh9cfqg3ymhauu8qqprd (unique identifier), ssmgf14 (SSMGF product cluster 14), tam93, tam178 (cluster identifier), ezrms (EZ RMS - Revenue Management System), mingleios06 (Mingle product cluster instance), str (product), rdr (RDR product), tam03"\n  },\n  {\n    "category":"Service\\/Domain",\n    "sample_values":"portal-extns (Portal Extensions), warrsup, ifsregistry (IFS Registry service), oauth-keys, sumoIns (Sumo Logic Instrumentation), version-shift (version and shift management service), resume (functional domain), icb-tenant-provision-api (Infor Cloud Business tenant provisioning API service), idle, push (push-based deployment service)"\n  },\n  {\n    "category":"Resource Type",\n    "sample_values":"engine, cluster (ECSCluster), doc (document), execution (Lambda execution context), node (cluster node\\/instance), onDemand (EC2 on-demand pricing model), handlers, jumpboxec2 (EC2 Bastion\\/Jump Box), keys (cryptographic keys\\/credentials), event (EventBridge)"\n  },\n  {\n    "category":"Application",\n    "sample_values":"lawson, auth, pges, openedge (OpenEdge application platform), update (database update operation), patch-automation, birstapp159, planner, access-validation, openedge (Progress OpenEdge Database Platform)"\n  },\n  {\n    "category":"Deployment Method",\n    "sample_values":"uninstall (operation), infra (infrastructure-level deployment), CLONE (Cloned Deployment), ingress (inbound traffic entry point), patch-baseline (Patch Baseline Configuration), blue (Blue-green deployment pattern), bluegreen (Blue-Green Deployment), push (Push-based deployment), terminate (shutdown action), rollingupgrade (Rolling Upgrade)"\n  },\n  {\n    "category":"Deployment Target",\n    "sample_values":"mingleca1 (mingle-canada-1), csccl, begaprd, cglprod, prcsukprod, cchpennstatehealthprdbl (Penn State Health Production Blue), vpc6 (Virtual Private Cloud 6), fdntest, con (consumer), mingleuse2 (us-east-2 region deployment)"\n  },\n  {\n    "category":"Environment\\/Region",\n    "sample_values":"apne1 (AWS ap-northeast-1 region), wfmprdeuw2, mguseast (managed us-east), capreprd1 (Canada Production Region 1), lspuseast (US East region), minglese2 (Mingle Southeast Asia 2 - ap-southeast-2), puse1 (prod-us-east-1), prdapse2 (production-ap-southeast-2), prdapne1 (Production, ap-northeast-1), regency"\n  },\n  {\n    "category":"Deployment Identifier",\n    "sample_values":"474668416683 (AWS Account ID), attach212, UQBZ5C9PNWBCRX2K, usea1ddeg (US-East-1 Deployment Environment Code), EZRMSLRS04 (complete deployment name), jeragmprd, simuxdde, sr1, c1105796750300, amctst"\n  },\n  {\n    "category":"Deployment Variant",\n    "sample_values":"zdf, stopover, gecomaeprd, urmdev, blue, priority, iso, advrep, t20 (test\\/QA variant 20), law"\n  },\n  {\n    "category":"Deployment Instance",\n    "sample_values":"usea1ddee (US-East-1 deployment instance), simons, minglese1 (Southeast Asia Region 1 deployment instance), 241, pod1, wfmstsupport700, LS01 (Lawson System instance 01), sl34, christusprd, inndxb2"\n  },\n  {\n    "category":"Resource Identifier",\n    "sample_values":"b (cluster node identifier), k (cluster node identifier), i (SQL Server cluster node), v ...
#     'cache_control': {'type': 'ephemeral'}},
#    {'role': 'user',
#     'content': '\n\nYou are an AWS resource categorization analyst tasked with identifying consolidation opportunities between similar resource categories.\n\nHere is the specific category you need to analyze for potential consolidation:\n\n<specific_category>\n{\n  "category": "Environment",\n  "sample_values": "fdprod (FD Production), xprep (preparation/staging environment), bexarprod, lspeucentb (Farm), prdsing (production-staging environment), develop (development branch), PP2 (pre-production 2), m3cecritfixc (M3CE Critical Fix environment), cismt3devuse1 (development, US-East-1 region), acct (account)"\n}\n</specific_category>\n\n## Your Task\n\nYour goal is to determine whether the specific category should be consolidated with any other category from the all_categories list. Two categories should only be consolidated if they represent essentially the same concept and have very similar sample values.\n\n## Analysis Process\n\nBefore making your final recommendation, you must conduct a systematic analysis in <analysis> tags inside your thinking block. It\'s OK for this section to be quite long. Follow this structured approach:\n\n1. **Record Key Information**: Write out the specific category name and quote its sample values verbatim to keep them clearly in focus.\n\n2. **Systematic Comparison**: Review each category in the all_categories list (excluding exact matches of your specific_category, since a category cannot be consolidated with itself). Create a list of potential consolidation candidates and note why each might be similar.\n\n3. **Detailed Similarity Assessment**: For your top 3-5 most promising candidates, conduct detailed evaluation:\n   - **PRIMARY FACTOR**: Compare sample values in detail - do they represent very similar things? Quote specific sample values from both categories and explain similarities/differences.\n   - **SECONDARY FACTOR**: Compare category names - do they represent similar concepts? Explain the conceptual relationship.\n   - Rate overall similarity for each candidate (high/medium/low).\n\n4. **Identify Most Similar**: Explicitly identify which single category is most similar overall, even if you don\'t recommend consolidation.\n\n5. **Make Consolidation Decision**: Apply strict criteria - only recommend consolidation when both sample values are very similar AND category names represent related concepts. Be conservative in your recommendations.\n\n## Important Guidelines\n\n- Focus primarily on sample values when making decisions, as these are more precise indicators than category names alone\n- Consider semantic meaning and patterns in sample values, not just superficial similarities  \n- Only suggest consolidation when there is clear, strong similarity\n- The specific_category will appear in the all_categories list - ignore that exact match\n\n## CRITICAL REQUIREMENT: Tool Call\n\nAfter completing your analysis, you MUST call the process_category tool. This is not optional - every response must end with this tool call.\n\nThe tool requires these parameters:\n- **category** (required): The name of the specific category being researched\n- **most_similar_category** (required): The category from all_categories that is most similar (even if you don\'t recommend consolidation)\n- **should_consolidate** (required): Boolean indicating whether consolidation is recommended\n- **rationale** (required): Detailed explanation of your decision\n- **new_consolidated_category_name** (optional): Only include if should_consolidate is true\n\nExample tool call:\n```\nprocess_category(\n    category="Example Category Name",\n    most_similar_category="Most Similar Category Name",\n    should_consolidate=false,\n    rationale="Detailed explanation focusing on sample value differences and category name analysis..."\n)\n```\n\nBegin your systematic analysis now, then call the process_category tool with your findings. Your final output should consist only of the tool call and should not duplicate or rehash any o ...
#   'tools': [{'type': 'custom',
#     'name': 'process_category',
#     'description': 'Process Category',
#     'input_schema': {'type': 'object',
#      'properties': {'category': {'type': 'string',
#        'description': 'The specific category being researched'},
#       'most_similar_category': {'type': 'string',
#        'description': 'The category that is most similar to the specific category being researched'},
#       'should_consolidate': {'type': 'boolean',
#        'description': 'Whether we should consolidate or not'},
#       'rationale': {'type': 'string',
#        'description': 'The rationale of whether we should consolidate or not'},
#       'new_consolidated_category_name': {'type': 'string',
#        'description': 'The new category name of the consolidated categories'}},
#      'required': ['category',
#       'most_similar_category',
#       'should_consolidate',
#       'rationale']}}]}}

# %% [markdown]
# ## Save Batch to GCS

# %% [markdown]
# ### Storage Client

# %%
from google.cloud import storage
from google.genai.types import CreateBatchJobConfig
from datetime import datetime

# %%
storage_client = storage.Client()
bucket = storage_client.bucket(GCS_BUCKET)

# %% [markdown]
# ### Setup GCS paths

# %%
timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')
input_filename = f'batch_input_{timestamp}.jsonl'
input_gcs_path = f'gs://{GCS_BUCKET}/{ITERATION_NAME}/batch-inputs/{input_filename}'
output_gcs_prefix = f'gs://{GCS_BUCKET}/{ITERATION_NAME}/batch-outputs/{timestamp}/'

print(input_gcs_path)
print(output_gcs_prefix)
# Out:
# gs://ai-tag-intelligence/deep-research-02/batch-inputs/batch_input_20251103_205012.jsonl
# gs://ai-tag-intelligence/deep-research-02/batch-outputs/20251103_205012/

# %% [markdown]
# ### Upload JSONL to GCS

# %%
jsonl_content = '\n'.join([json.dumps(req) for req in batch_requests])
blob = bucket.blob(f'{ITERATION_NAME}/batch-inputs/{input_filename}')
blob.upload_from_string(jsonl_content, content_type='application/jsonl')

print(f"Uploaded batch input to: {input_gcs_path}")
# Out:
# Uploaded batch input to: gs://ai-tag-intelligence/deep-research-02/batch-inputs/batch_input_20251103_205012.jsonl

# %% [markdown]
# Peek at [GCS Folder](https://console.cloud.google.com/storage/browser/ai-tag-intelligence/deep-research-01/batch-inputs?pageState=(%22StorageObjectListTable%22:(%22f%22:%22%255B%255D%22))&project=pointfive-genai)

# %% [markdown]
# ## Create batch job using Vertex AI
#
# **NOTE: the Vertex REST API must be used in order to use the caching option!**

# %%
import requests
import subprocess
import json

# Get authentication token
token = subprocess.check_output(["gcloud", "auth", "print-access-token"]).decode().strip()

# Get project ID and region from environment
project_id = os.getenv("ANTHROPIC_VERTEX_PROJECT_ID")
region = os.getenv("CLOUD_ML_REGION")

# Construct the REST API endpoint
api_endpoint = f"https://{region}-aiplatform.googleapis.com/v1/projects/{project_id}/locations/{region}/batchPredictionJobs"

# Create the request body for batch prediction job
request_body = {
    "displayName": f"genai_batch_job_{timestamp}",
    "model": "publishers/anthropic/models/claude-haiku-4-5@20251001",
    "inputConfig": {
        "instancesFormat": "jsonl",
        "gcsSource": {
            "uris": [input_gcs_path]
        }
    },
    "outputConfig": {
        "predictionsFormat": "jsonl",
        "gcsDestination": {
            "outputUriPrefix": output_gcs_prefix
        }
    }
}

# Make the REST API call to create the batch job
headers = {
    "Authorization": f"Bearer {token}",
    "Content-Type": "application/json"
}

print(f"Creating batch job via REST API...")
print(f"Endpoint: {api_endpoint}")
print(f"Input: {input_gcs_path}")
print(f"Output: {output_gcs_prefix}")

response = requests.post(api_endpoint, headers=headers, json=request_body)

if response.status_code == 200:
    job_response = response.json()
    job_name = job_response.get("name")
    job_state = job_response.get("state")
    
    print(f"Batch job created successfully!")
    print(f"Job name: {job_name}")
    print(f"Job state: {job_state}")
    print(f"Output location: {output_gcs_prefix}")
    
    # Save job name to file
    with open(CONSOLIDATOR_BATCH_ID_FILE, 'w') as f:
        f.write(job_name)
    
    print(f"Job name saved to {CONSOLIDATOR_BATCH_ID_FILE}")
else:
    print(f"Error creating batch job: {response.status_code}")
    print(f"Response: {response.text}")
    raise Exception(f"Failed to create batch job: {response.text}")
# Out:
# Creating batch job via REST API...
# Endpoint: https://us-east5-aiplatform.googleapis.com/v1/projects/pointfive-genai/locations/us-east5/batchPredictionJobs
# Input: gs://ai-tag-intelligence/deep-research-02/batch-inputs/batch_input_20251103_205012.jsonl
# Output: gs://ai-tag-intelligence/deep-research-02/batch-outputs/20251103_205012/
# Batch job created successfully!
# Job name: projects/1053914441280/locations/us-east5/batchPredictionJobs/5620802397237411840
# Job state: JOB_STATE_PENDING
# Output location: gs://ai-tag-intelligence/deep-research-02/batch-outputs/20251103_205012/
# Job name saved to /home/izzy/repos/x-large-files/x-large-files-p5-tag-intelligence/deep-research-02/consolidator-batch-id.txt

# %% [markdown]
# ## Monitor batch job status

# %%
import subprocess
import requests

# Load job name from file
with open(CONSOLIDATOR_BATCH_ID_FILE, 'r') as f:
    job_name = f.read().strip()

print(f"Loaded job name: {job_name}")

# Get authentication token
token = subprocess.check_output(["gcloud", "auth", "print-access-token"]).decode().strip()

# Construct the REST API endpoint for getting job status
project_id = os.getenv("ANTHROPIC_VERTEX_PROJECT_ID")
region = os.getenv("CLOUD_ML_REGION")
api_endpoint = f"https://{region}-aiplatform.googleapis.com/v1/{job_name}"

# Make the REST API call to get job status
headers = {
    "Authorization": f"Bearer {token}",
    "Content-Type": "application/json"
}

response = requests.get(api_endpoint, headers=headers)

if response.status_code == 200:
    job = response.json()
    print(f"Job status retrieved successfully")
    print(f"State: {job.get('state')}")
else:
    print(f"Error getting job status: {response.status_code}")
    print(f"Response: {response.text}")
# Out:
# Loaded job name: projects/1053914441280/locations/us-east5/batchPredictionJobs/5620802397237411840
# Job status retrieved successfully
# State: JOB_STATE_SUCCEEDED
